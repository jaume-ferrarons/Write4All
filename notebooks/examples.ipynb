# %% [markdown]
# # Examples
#
# In this notebook I show how the suggestions to improve some examples.

# %%
# Add parent directory to path
import os
import sys
sys.path.append(os.path.abspath('..'))

from IPython.display import display, HTML, Markdown
import PIL
from review import process_text, process_image

gemini_1_0 = "Gemini 1.0 Pro"
gemini_1_5 = "Gemini 1.5 Pro (latest)"
gemini_1_0_vision = "Gemini 1.0 Pro Vision"

# %% [markdown]
# ## Text examples

# %%
def demo_text(original_text: str):
    display(HTML(f"<h1>Original text</h1>{original_text}"))
    display(HTML(process_text(text=original_text, model=gemini_1_5)))

text_examples = [
    "Mankind has always been fascinated by the stars.",
    "The blacklist is too large.",
    "The average user prefers his information presented visually.",
    "Native English speaker.",
    "I'm totally OCD about keeping my desk clean.",
    "People of that religion are always so conservative.",
    "You speak English really well for a foreigner.",
    "He's too skinny to play sports.",
    "This sentence is in English.",
]
for text in text_examples:
    demo_text(text)
# Out:
# <h1>Original text</h1>Mankind has always been fascinated by the stars.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'><span title="gender-exclusive"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>Mankind</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>Humanity</span></span> has always been fascinated by the stars.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>Mankind</td><td>Humanity</td><td>gender-exclusive</td><td>Mankind excludes women and non-binary people, while Humanity is inclusive of all genders.</td></tr></table>
# <h1>Original text</h1>The blacklist is too large.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'>The <span title="others"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>blacklist</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>blocklist</span></span> is too large.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>blacklist</td><td>blocklist</td><td>others</td><td>blacklist carries negative racial connotations, blocklist is racially neutral</td></tr></table>
# <h1>Original text</h1>The average user prefers his information presented visually.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'>The average user prefers <span title="gender-exclusive"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>his</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>their</span></span> information presented visually.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>his</td><td>their</td><td>gender-exclusive</td><td>Using 'their' instead of 'his' avoids assuming the gender of the user.</td></tr></table>
# <h1>Original text</h1>Native English speaker.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'><span title="others"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>Native English speaker</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>Fluent English speaker</span></span>.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>Native English speaker</td><td>Fluent English speaker</td><td>others</td><td>'Native' can be discriminatory towards people who speak English as a second language and are also fluent.</td></tr></table>
# <h1>Original text</h1>I'm totally OCD about keeping my desk clean.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'>I'm totally <span title="ableism"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>OCD</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>organized</span></span> about keeping my desk clean.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>OCD</td><td>organized</td><td>ableism</td><td>OCD is a serious mental health condition and should not be used lightly</td></tr></table>
# <h1>Original text</h1>People of that religion are always so conservative.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'><span title="religion/culture"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>People of that religion are always so conservative</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>Some people hold conservative values</span></span>.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>People of that religion are always so conservative</td><td>Some people hold conservative values</td><td>religion/culture</td><td>Generalizing about an entire religious group fosters stereotypes and is not inclusive</td></tr></table>
# <h1>Original text</h1>You speak English really well for a foreigner.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'>You speak English really well <span title="microagressions"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 5px 5px 5px; padding-left: 5px; padding-right: 5px;'>for a foreigner</span></span>.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>for a foreigner</td><td></td><td>microagressions</td><td>This phrase implies that foreigners are not expected to speak English well, which is a harmful stereotype.</td></tr></table>
# <h1>Original text</h1>He's too skinny to play sports.
# <h1>Reviewed text</h1><pre style='white-space: pre-wrap;'>He's too <span title="body-stigma"><span style='background-color:#FF5555; color:black; text-decoration:line-through; text-decoration-thickness: 2px; min-height: 22px; display: inline-block; border-radius: 5px 0 0 5px; padding-left: 5px;'>skinny</span><span style='background-color:#55FF55; color:black; min-height: 22px; display: inline-block; border-radius: 0 5px 5px 0; padding-right: 5px;'>thin</span></span> to play sports.</pre><h1>Explanation</h1><table><tr><th>Term</th><th>Fix</th><th>Type</th><th>Reason</th></tr><tr><td>skinny</td><td>thin</td><td>body-stigma</td><td>Skinny has a negative connotation and might perpetuate body image issues</td></tr></table>
# <h1>Original text</h1>This sentence is in English.
# <h1>No issues found in the text 🎉🎉🎉</h1>

# %% [markdown]
# ## Images

# %%
def demo_image(image_path: str):
    # display(Image(image_path, width=600))
    image = PIL.Image.open(image_path)
    image.thumbnail((600, 600))
    display(image)
    response = process_image(image=image, model=gemini_1_0_vision)
    display(Markdown(response))

demo_image("../static/images/CEOs.png")
demo_image("../static/images/meat_grid.png")
demo_image("../static/images/crosses.jpg") # Author: Gerd Altmann - https://pixabay.com/users/geralt-9301/
demo_image("../static/images/elephants.jpg") # Author: Gerd Altmann - https://pixabay.com/users/geralt-9301/
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x291>
#  The image is exclusive because it only shows white men. This is a problem because it does not represent the diversity of the real world. To make the image more inclusive, we could replace some of the white men with women and people of color.
#
# | Problem | Solution |
# |---|---|
# | The image only shows white men. | Replace some of the white men with women and people of color. |
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x177>
#  The image is a Pinterest board of recipes for beef dishes. It is exclusive because it does not include any recipes for vegetarian or vegan dishes. This could be a problem for people who are looking for more plant-based options.
#
# | Problem | Solution |
# |---|---|
# | The image does not include any recipes for vegetarian or vegan dishes. | The image could be made more inclusive by including a few recipes for vegetarian or vegan dishes. |
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>
#  The image is of three crosses on a hill. It is a symbol of Christianity. The image is exclusive because it only represents one religion.
#
# | Problem | Solution |
# |---|---|
# | The image only represents one religion. | The image could be changed to include symbols from other religions. |
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x339>
#  The image is of two elephants walking in a grassy field. The sun is setting in the background. The image is peaceful and serene.
#
# There are no people in the image, so it is not possible to say whether or not it is inclusive. However, the image is not exclusive because it does not depict any group of people as being better or worse than any other.
